# %% [markdown]
# # 1) Установка библиотек

# %%
# !pip -qq install langchain
# !pip -qq install langchain-core
# !pip -qq install langchain-community
# !pip -qq install langchain-classic
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 65.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 73.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 7.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 5.5 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.32.5 which is incompatible.

# %% [markdown]
# # 2) Установка Ollama и Llama3

# %% [markdown]
# Скопируйте и последовательно запустите команды в терминале:
# ```
# curl https://ollama.ai/install.sh | sed 's#https://ollama.ai/download#https://github.com/jmorganca/ollama/releases/download/v0.1.17#' | sh
# ollama serve &
# ollama pull llama3
# ```
#
# Дождитесь сообщения: "success"

# %%
from langchain_community.llms import Ollama
from langchain_community.document_loaders import WebBaseLoader
from langchain_classic.chains.summarize import load_summarize_chain

loader = WebBaseLoader("https://www.apple.com/")
docs = loader.load()

llm = Ollama(model="llama3")
chain = load_summarize_chain(llm, chain_type="stuff")

result = chain.invoke(docs)
result
# Out:
# {'input_documents': [Document(metadata={'source': 'https://www.apple.com/', 'title': 'Apple', 'language': 'en-US'}, page_content='\n\n\n\n\n\n\n\n\n\n\nApple\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nApple\n\nAppleStoreMaciPadiPhoneWatch\nVisionAirPodsTV & HomeEntertainmentAccessoriesSupport\n\n\n0+\n\n\n\n\n\n\n\n\n\n\t\t\t\t\t\t\t\t\t\tOrder by 12/22 for free delivery of in‑stock items by 12/24. See checkout for specific delivery dates and options. Shop\n\n\n\n\n\n\n\n\n\n\n\xa0\n\t\t\t\t\t\t\t\t\t\n\nWrapping up this\xa0special season.\nThere’s still time to make their holiday one of a kind.\n\nShop gifts\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0\n\niPhone\nSay hello to the latest generation of iPhone.\n\nLearn more\nShop iPhone\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0\n\nAirPods Pro 3\nThe world’s best in-ear Active Noise Cancellation.\n\nLearn more\nBuy\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0\n\n\niPad Air\nNow supercharged by the M3 chip.\n\nLearn more\nBuy\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\xa0\n\n\niPad Ai
# ...

# %%
from IPython.display import display, Markdown, Latex

# %%
Markdown(result['output_text'])
# Out:
# The webpage appears to be the official website of Apple, a technology company that designs, manufactures, and markets consumer electronics, computer software, and online services. The page is promoting various Apple products and services, including:
#
# 1. New iPhone models
# 2. AirPods Pro 3 with Active Noise Cancellation
# 3. iPad Air with M3 chip
# 4. MacBook Air with M4 chip
# 5. Apple Watch Series 11
#
# The page also highlights various entertainment options, such as streaming services like Apple TV+ and Apple Original series.
#
# Additionally, the webpage offers information on Apple's gift card program, trade-in program, and financing options. It also provides details on how to shop, learn more about products, and access support resources.
#
# Overall, the website is promoting Apple's wide range of products and services, as well as its commitment to accessibility, education, and environmental sustainability.

# %% [markdown]
# # Задание
# Опробуйте код на выбранном вами сайте и субъективно оцените качество резюме текста.
